# %% [markdown]
# # Outcome Model Exploration
#
# This notebook is for exploring data, features, and model behavior.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torch
from pathlib import Path
import sys

# Add project root to path
sys.path.append(str(Path.cwd().parent))

print("Setup complete!")

# %% [markdown]
# ## Load Dataset

# %%
# Load labeled dataset
dataset_path = "../data/datasets/outcome_train.pt"

if Path(dataset_path).exists():
    data = torch.load(dataset_path)
    print(f"Dataset loaded: {data['features'].shape}")
    print(f"Labels: {data['labels'].shape}")
    print(f"Feature names: {len(data.get('feature_names', []))}")
else:
    print(f"Dataset not found at {dataset_path}")
    print("Run labeler first: python src/layer3_model/training/labeler.py")

# %% [markdown]
# ## Explore Label Distribution

# %%
# TODO: Add label distribution analysis
# - Plot bar chart of long/short/skip counts
# - Analyze max_up_R and max_down_R distributions
# - Check for data imbalance

# %% [markdown]
# ## Visualize Features

# %%
# TODO: Add feature visualization
# - Plot feature distributions
# - Check for outliers
# - Correlation heatmap

# %% [markdown]
# ## Model Analysis

# %%
# TODO: Add model analysis
# - Load trained model
# - Visualize predictions on test set
# - Confusion matrix
# - Feature importance (if applicable)
